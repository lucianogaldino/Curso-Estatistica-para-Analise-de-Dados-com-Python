# %% [markdown]
# ## TESTE MANN WHITNEY (soma de postos de Wilcoxon)

# %% [markdown]
# Teste Não paramétrico
#
# Duas amostras independentes

# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/Cursos_Udemy/curso_estatistica_python/enem_2019_tratado.csv',
                      sep=',', encoding='iso-8859-1')

# %%
enem_sp.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE  ...  COMP5  NOTA_REDACAO INTERNET
# 0     1,90E+11            Santa Isabel     22  ...  200.0         940.0      Sim
# 1     1,90E+11               São Paulo     17  ...  200.0         880.0      Não
# 2     1,90E+11   São Bernardo do Campo     19  ...  100.0         560.0      Sim
# 3     1,90E+11              Embu-Guaçu     17  ...   80.0         560.0      Sim
# 4     1,90E+11               Guarulhos     23  ...  160.0         880.0      Sim
#
# [5 rows x 28 columns]

# %% [markdown]
# Objetivo:
# Analisar a diferença entre as MEDIANAS de mulheres e homens para as notas do colégio x.

# %%
colegiox = enem_sp.loc[enem_sp.CO_ESCOLA == 35017632.0]

# %%
colegiox.shape
# Out:
# (41, 28)

# %%
colegiox.head()
# Out:
#    NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE  ...  COMP5  NOTA_REDACAO INTERNET
# 37     1,90E+11        Águas de Lindóia     18  ...   20.0         340.0      Sim
# 44     1,90E+11        Águas de Lindóia     17  ...  160.0         720.0      Não
# 52     1,90E+11        Águas de Lindóia     17  ...   80.0         560.0      Não
# 65     1,90E+11        Águas de Lindóia     17  ...   40.0         520.0      Sim
# 79     1,90E+11        Águas de Lindóia     18  ...  140.0         640.0      Sim
#
# [5 rows x 28 columns]

# %%
colegiox_mulher = colegiox.loc[colegiox.SEXO == 'F']

# %%
colegiox_mulher.head()
# Out:
#    NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE  ...  COMP5  NOTA_REDACAO INTERNET
# 44     1,90E+11        Águas de Lindóia     17  ...  160.0         720.0      Não
# 52     1,90E+11        Águas de Lindóia     17  ...   80.0         560.0      Não
# 79     1,90E+11        Águas de Lindóia     18  ...  140.0         640.0      Sim
# 84     1,90E+11        Águas de Lindóia     19  ...   20.0         360.0      Sim
# 91     1,90E+11        Águas de Lindóia     18  ...   80.0         560.0      Sim
#
# [5 rows x 28 columns]

# %%
colegiox_mulher.shape
# Out:
# (28, 28)

# %%
colegiox_homem = colegiox.loc[colegiox.SEXO == 'M']

# %%
colegiox_homem.shape
# Out:
# (13, 28)

# %%
colegiox_homem.head()
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  ...  NOTA_REDACAO INTERNET
# 37         1,90E+11        Águas de Lindóia  ...         340.0      Sim
# 65         1,90E+11        Águas de Lindóia  ...         520.0      Sim
# 85         1,90E+11        Águas de Lindóia  ...         680.0      Sim
# 108151     1,90E+11        Águas de Lindóia  ...         660.0      Sim
# 182519     1,90E+11        Águas de Lindóia  ...         520.0      Sim
#
# [5 rows x 28 columns]

# %% [markdown]
# 1) Analisar a classificação das variáveis

# %%
colegiox.dtypes
# Out:
# NU_INSCRICAO                object
# NO_MUNICIPIO_RESIDENCIA     object
# IDADE                        int64
# SEXO                        object
# TP_ESTADO_CIVIL              int64
# RACA                        object
# TP_NACIONALIDADE             int64
# TP_ST_CONCLUSAO              int64
# ESCOLA                      object
# CO_ESCOLA                  float64
# NO_MUNICIPIO_ESC            object
# TP_PRESENCA_CN               int64
# TP_PRESENCA_CH               int64
# TP_PRESENCA_LC               int64
# TP_PRESENCA_MT               int64
# NOTA_CN                    float64
# NOTA_CH                    float64
# NOTA_LC                    float64
# NOTA_MT                    float64
# TP_LINGUA                   object
# TP_STATUS_REDACAO          float64
# COMP1                      float64
# COMP2                      float64
# COMP3                      float64
# COMP4                      float64
# COMP5                      float64
# NOTA_REDACAO               float64
# INTERNET                    object
# dtype: object

# %% [markdown]
# 2) Analisar valores missing

# %%
colegiox.isnull().sum()
# Out:
# NU_INSCRICAO               0
# NO_MUNICIPIO_RESIDENCIA    0
# IDADE                      0
# SEXO                       0
# TP_ESTADO_CIVIL            0
# RACA                       0
# TP_NACIONALIDADE           0
# TP_ST_CONCLUSAO            0
# ESCOLA                     0
# CO_ESCOLA                  0
# NO_MUNICIPIO_ESC           0
# TP_PRESENCA_CN             0
# TP_PRESENCA_CH             0
# TP_PRESENCA_LC             0
# TP_PRESENCA_MT             0
# NOTA_CN                    0
# NOTA_CH                    0
# NOTA_LC                    0
# NOTA_MT                    0
# TP_LINGUA                  0
# TP_STATUS_REDACAO          0
# COMP1                      0
# COMP2                      0
# COMP3                      0
# COMP4                      0
# COMP5                      0
# NOTA_REDACAO               0
# INTERNET                   0
# dtype: int64

# %% [markdown]
# 3) Analisar Normalidade

# %% [markdown]
# CRITÉRIOS:
#
# NÍVEL DE SIGNIFICÂNCIA DE 0,05 ou 5% (MAIS UTILIZADO)
#
# QUANDO p > 0,05 (distribuição normal).

# %%
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt

# %%
# Teste Shapiro-Wilk - MATEMÁTICA
stats.shapiro(colegiox_mulher.NOTA_MT)
# Out:
# (0.7194502353668213, 5.43060059499112e-06)

# %%
stats.probplot(colegiox_mulher['NOTA_MT'], dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
stats.shapiro(colegiox_homem.NOTA_MT)
# Out:
# (0.8659597635269165, 0.04620101675391197)

# %%
stats.probplot(colegiox_homem['NOTA_MT'], dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
# Teste Shapiro-Wilk - CIÊNCIAS DA NATUREZA
stats.shapiro(colegiox_mulher.NOTA_CN)
# Out:
# (0.7065989375114441, 3.5363013921596576e-06)

# %%
stats.probplot(colegiox_mulher['NOTA_CN'], dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
stats.shapiro(colegiox_homem.NOTA_CN)
# Out:
# (0.7647998332977295, 0.0026814276352524757)

# %%
stats.probplot(colegiox_homem['NOTA_CN'], dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# **TESTE MANN WHITNEY**
#
# Comparação das medianas das notas homens e mulheres do colégio X.

# %% [markdown]
# Ho = NÃO HÁ DIFERENÇA ENTRE AS MEDIANAS DAS NOTAS DE HOMENS E MULHERES : p > 0.05
#
# Ha = HÁ DIFERENÇA ENTRE AS MEDIANAS DAS NOTAS ENTRE HOMENS E MULHERES : p <= 0.05

# %%
import scipy.stats as stats

# %%
stat, p = stats.mannwhitneyu(colegiox_mulher.NOTA_MT, colegiox_homem.NOTA_MT)
print('Estatística de teste: {}'.format(stat.round(2)))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 127.0
# p-valor: 0.06339241814609269

# %%
stat, p = stats.mannwhitneyu(colegiox_mulher.NOTA_CN, colegiox_homem.NOTA_CN)
print('Estatística de teste: {}'.format(stat.round(2)))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 136.0
# p-valor: 0.10119800798647943

# %%
colegiox_mulher.NOTA_MT.describe()
# Out:
# count     28.000000
# mean     437.928571
# std      146.875707
# min       42.400000
# 25%      413.375000
# 50%      485.150000
# 75%      512.550000
# max      599.500000
# Name: NOTA_MT, dtype: float64

# %%
colegiox_homem.NOTA_MT.describe()
# Out:
# count     13.000000
# mean     501.515385
# std      164.496808
# min       59.500000
# 25%      442.600000
# 50%      513.900000
# 75%      588.800000
# max      705.700000
# Name: NOTA_MT, dtype: float64

# %%
colegiox_mulher.NOTA_CN.describe()
# Out:
# count     28.000000
# mean     397.785714
# std      132.791189
# min       43.400000
# 25%      381.875000
# 50%      420.300000
# 75%      480.275000
# max      521.600000
# Name: NOTA_CN, dtype: float64

# %%
colegiox_homem.NOTA_CN.describe()
# Out:
# count     13.000000
# mean     290.130769
# std      202.857069
# min       46.300000
# 25%       49.800000
# 50%      391.500000
# 75%      460.200000
# max      523.100000
# Name: NOTA_CN, dtype: float64

# %%
import plotly.express as px

# %%
grafico = px.box(colegiox, x = 'SEXO', y="NOTA_MT")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4dc0785-bcea-41c8-be61-36acfa02834e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4dc0785-bcea-41c8-be61-36acfa02834e")) {
#                     Plotly.newPlot(
#                         'f4dc0785-bcea-41c8-be61-36acfa02834e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "SEXO=%{x}<br>NOTA_MT=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["M", "F", "F", "M", "F", "F", "M", "F", "F", "F", "F", "F", "M", "F", "F", "F", "F", "M", "M", "F", "F", "F", "M", "F", "F", "F", "F", "M", "F", "M", "M", "M", "F", "M", "F", "F", "F", "F", "F", "F", "M"], "x0": " ", "xaxis": "x", "y": [537.1, 451.9, 506.4, 59.5, 510.6, 420.6, 508.2, 537.9, 500.3, 42.4, 54.2, 537.5, 705.3, 518.4, 480.8, 414.6, 479.9, 480.9, 555.1, 599.5, 469.2, 544.9, 705.7, 409.7, 497.1, 491.2, 60.0, 606.1, 402.9, 588.8, 439.3, 377.2, 409.1, 442.6, 489.5, 502.1, 559.5, 562.9, 360.2, 448.7, 513.9], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %%
grafico = px.box(colegiox, x = 'SEXO', y="NOTA_CN")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c375dcf1-b873-4e25-8835-7143766b4d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c375dcf1-b873-4e25-8835-7143766b4d27")) {
#                     Plotly.newPlot(
#                         'c375dcf1-b873-4e25-8835-7143766b4d27',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "SEXO=%{x}<br>NOTA_CN=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["M", "F", "F", "M", "F", "F", "M", "F", "F", "F", "F", "F", "M", "F", "F", "F", "F", "M", "M", "F", "F", "F", "M", "F", "F", "F", "F", "M", "F", "M", "M", "M", "F", "M", "F", "F", "F", "F", "F", "F", "M"], "x0": " ", "xaxis": "x", "y": [46.3, 505.9, 449.4, 468.6, 414.3, 397.8, 469.1, 436.3, 464.8, 465.8, 497.6, 424.1, 50.7, 518.3, 516.8, 421.9, 494.4, 460.2, 349.3, 381.2, 49.3, 418.7, 454.7, 486.5, 43.4, 392.8, 366.5, 49.4, 371.4, 47.8, 391.5, 411.2, 405.8, 49.8, 412.1, 382.1, 521.6, 49.5, 478.2, 371.5, 523.1], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %% [markdown]
# **Conclusão:** Estatisticamente, com intervalo de confiança de 95%, não se pode concluir que a mediana das notas de Matemática e Ciências da natureza do colegio X sejam diferentes entre homens e mulheres.
