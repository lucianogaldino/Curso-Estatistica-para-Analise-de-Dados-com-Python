# %% [markdown]
# ## **Medidas de tendência central**

# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/Cursos_Udemy/curso_estatistica_python/enem_2019_tratado.csv',
                      sep=',', encoding='iso-8859-1')

# %% [markdown]
# ## Média

# %%
enem_sp['IDADE'].mean()
# Out:
# 20.593387206464776

# %%
enem_sp.IDADE.mean()
# Out:
# 20.593387206464776

# %%
round(enem_sp['IDADE'].mean(),2)
# Out:
# 20.59

# %%
enem_sp.NOTA_REDACAO.mean()
# Out:
# 593.0183221986639

# %%
enem_sp['NOTA_MT'].mean()
# Out:
# 497.5942403088341

# %%
enem_sp.NOTA_CN.mean()
# Out:
# 449.9170004400505

# %%
enem_sp.NOTA_CH.mean()
# Out:
# 482.22805396649204

# %%
enem_sp.NOTA_LC.mean()
# Out:
# 491.9412621514665

# %% [markdown]
# ## Mediana

# %%
enem_sp['IDADE'].median()
# Out:
# 18.0

# %%
enem_sp.NOTA_REDACAO.median()
# Out:
# 600.0

# %%
enem_sp.NOTA_MT.median()
# Out:
# 511.8

# %%
enem_sp.NOTA_CN.median()
# Out:
# 478.1

# %%
enem_sp.NOTA_CH.median()
# Out:
# 523.7

# %%
enem_sp['NOTA_LC'].median()
# Out:
# 538.3

# %%
enem_sp.describe()
# Out:
#                IDADE  TP_ESTADO_CIVIL  ...          COMP5   NOTA_REDACAO
# count  499940.000000    499940.000000  ...  499940.000000  499940.000000
# mean       20.593387         1.053206  ...      97.200704     593.018322
# std         6.465291         0.380866  ...      57.787427     170.536724
# min        12.000000         0.000000  ...       0.000000       0.000000
# 25%        17.000000         1.000000  ...      60.000000     500.000000
# 50%        18.000000         1.000000  ...     100.000000     600.000000
# 75%        21.000000         1.000000  ...     140.000000     680.000000
# max        91.000000         4.000000  ...     200.000000    1000.000000
#
# [8 rows x 20 columns]

# %%
round(enem_sp.describe(),1)
# Out:
#           IDADE  TP_ESTADO_CIVIL  ...     COMP5  NOTA_REDACAO
# count  499940.0         499940.0  ...  499940.0      499940.0
# mean       20.6              1.1  ...      97.2         593.0
# std         6.5              0.4  ...      57.8         170.5
# min        12.0              0.0  ...       0.0           0.0
# 25%        17.0              1.0  ...      60.0         500.0
# 50%        18.0              1.0  ...     100.0         600.0
# 75%        21.0              1.0  ...     140.0         680.0
# max        91.0              4.0  ...     200.0        1000.0
#
# [8 rows x 20 columns]

# %% [markdown]
# ## Moda

# %%
enem_sp['IDADE'].mode()
# Out:
# 0    17
# dtype: int64

# %%
enem_sp.NOTA_REDACAO.mode()
# Out:
# 0    600.0
# dtype: float64

# %%
enem_sp.NOTA_MT.mode()
# Out:
# 0    433.8
# dtype: float64

# %%
enem_sp.NOTA_CN.mode()
# Out:
# 0    481.8
# dtype: float64

# %%
enem_sp.NOTA_CH.mode()
# Out:
# 0    0.0
# dtype: float64

# %%
enem_sp.NOTA_LC.mode()
# Out:
# 0    55.2
# dtype: float64

# %% [markdown]
# ## Distribuição

# %%
enem_sp.COMP3.mode()
# Out:
# 0    120.0
# dtype: float64

# %%
enem_sp.COMP3.mean()
# Out:
# 118.76069128295396

# %%
enem_sp.COMP3.median()
# Out:
# 120.0

# %%
import plotly.express as px

# %%
grafico =  px.histogram (enem_sp,  x = "COMP3", nbins=15) 
grafico.update_layout(width=400,height=400,title_text='Notas do componente 3 da redação - Enem SP 2019') 
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
enem_sp.COMP2.mode()
# Out:
# 0    120.0
# dtype: float64

# %%
enem_sp.COMP2.mean()
# Out:
# 127.06680801696204

# %%
enem_sp.COMP2.median()
# Out:
# 120.0

# %%
import plotly.express as px
grafico =  px.histogram (enem_sp,  x = "COMP2", nbins=15) 
grafico.update_layout(width=400,height=400,title_text='Notas Componente 2: Redação - Enem SP 2019') 
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
